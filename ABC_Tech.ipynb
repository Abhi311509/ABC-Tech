# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhi311509/ABC-Tech/blob/main/ABC_Tech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymysql
# !pip install mysql-connector
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os
import mysql.connector
import pandas as pd
import numpy as np

# %%
output= pd.read_csv('ABC.csv')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
'''## Check the number of databases available on the server
cursor=connection.cursor()
cursor.execute('show databases')
for i in cursor:
    print(i)'''
# Out:
# ('information_schema',)
# ('project_itsm',)

# %%
db_tables=pd.read_sql_query('show tables',connection)
print(db_tables)
# Out:
#   Tables_in_project_itsm
# 0           dataset_list

# %%
'''query = "select * from dataset_list" # SQL statement
output = pd.read_sql(query,connection)
print(output.shape)'''
# Out:
# (46606, 25)

# %%
pd.set_option('display.max_columns',25)

# %%
output
# Out:
#        Unnamed: 0    CI_Name          CI_Cat                 CI_Subcat  \
# 0               0  SUB000508  subapplication     Web Based Application
# 1               1  WBA000124     application     Web Based Application
# 2               2  DTA000024     application       Desktop Application
# 3               3  WBA000124     application     Web Based Application
# 4               4  WBA000124     application     Web Based Application
# ...           ...        ...             ...                       ...
# 46601       46601  SBA000464     application  Server Based Application
# 46602       46602  SBA000461     application  Server Based Application
# 46603       46603  LAP000019        computer                    Laptop
# 46604       46604  WBA000058     application     Web Based Application
# 46605       46605  DCE000077        hardware       DataCenterEquipment
#
#              WBS Incident_ID  Status Impact Urgency  Priority  ...  \
# ...

# %%
output.isnull().sum()
# Out:
# CI_Name                       0
# CI_Cat                        0
# CI_Subcat                     0
# WBS                           0
# Incident_ID                   0
# Status                        0
# Impact                        0
# Urgency                       0
# Priority                      0
# number_cnt                    0
# Category                      0
# KB_number                     0
# Alert_Status                  0
# No_of_Reassignments           0
# Open_Time                     0
# Reopen_Time                   0
# Resolved_Time                 0
# Close_Time                    0
# Handle_Time_hrs               0
# Closure_Code                  0
# No_of_Related_Interactions    0
# Related_Interaction           0
# No_of_Related_Incidents       0
# No_of_Related_Changes         0
# Related_Change                0
# dtype: int64

# %%
output.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46606 entries, 0 to 46605
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   CI_Name                     46606 non-null  object
#  1   CI_Cat                      46606 non-null  object
#  2   CI_Subcat                   46606 non-null  object
#  3   WBS                         46606 non-null  object
#  4   Incident_ID                 46606 non-null  object
#  5   Status                      46606 non-null  object
#  6   Impact                      46606 non-null  object
#  7   Urgency                     46606 non-null  object
#  8   Priority                    46606 non-null  object
#  9   number_cnt                  46606 non-null  object
#  10  Category                    46606 non-null  object
#  11  KB_number                   46606 non-null  object
#  12  Alert_Status                46606 non-null  object
# ...

# %%
def value_count(df):
  for column in df:
    print()
    print('The value counts of {} column is'.format('\033[1m'+ column + '\033[0m'))
    print()
    print(df[column].value_counts())
    print('------------------------------------------------------------------')

# %%
value_count(output)
# Out:
# The value counts of CI_Name column is
#
# SUB000456    3050
# SBA000263    2176
# SBA000607    1743
# SBA000462    1698
# WBA000058    1614
#              ...
# LAP001572       1
# LAP000809       1
# LAP000513       1
# CBD000266       1
# SWT000008       1
# Name: CI_Name, Length: 3019, dtype: int64
# ------------------------------------------------------------------
#
# The value counts of CI_Cat column is
#
# application             32900
# subapplication           7782
# computer                 3643
# storage                   703
# hardware                  442
# software                  333
# database                  214
# displaydevice             212
# officeelectronics         152
#                           111
# networkcomponents         107
# applicationcomponent        5
# Phone                       2
# Name: CI_Cat, dtype: int64
# ------------------------------------------------------------------
#
# The value counts of CI_Subcat column is
#
# ...

# %%
def space(df):
  for column in df:
    df[column] = df[column].str.replace(r'[\x00-\x19]', '').replace('', 'miss')
    if output[column].str.contains('miss').any():
       print('Total {} replacement happened for {} column '.format(df[column].value_counts()['miss'],'\033[4m'+ column + '\033[0m'))

# %%
space(output)
# Out:
# <ipython-input-20-544117f680ba>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df[column] = df[column].str.replace(r'[\x00-\x19]', '').replace('', 'miss')
# Total 111 replacement happened for CI_Cat column
# Total 111 replacement happened for CI_Subcat column
# Total 1 replacement happened for No_of_Reassignments column
# Total 44322 replacement happened for Reopen_Time column
# Total 1780 replacement happened for Resolved_Time column
# Total 1 replacement happened for Handle_Time_hrs column
# Total 460 replacement happened for Closure_Code column
# Total 114 replacement happened for No_of_Related_Interactions column
# Total 45384 replacement happened for No_of_Related_Incidents column
# Total 46046 replacement happened for No_of_Related_Changes column
# Total 46046 replacement happened for Related_Change column

# %%
output.to_csv('ABC.csv')
